# %%
import pandas as pd

# %%
data = r"clean_cad.csv"
clean_cad = pd.read_csv(data)
clean_cad["Call Time"] = pd.to_datetime(clean_cad["Call Time"], errors='coerce')
clean_cad
# Out:
#          Unnamed: 0           Call Time Reason for Dispatch Call Sign  \
# 0                 0 2016-01-01 00:00:04             ASSAULT      5E57
# 1                 1 2016-01-01 00:00:04             ASSAULT      5E57
# 2                 2 2016-01-01 00:00:04             ASSAULT      5E57
# 3                 3 2016-01-01 00:00:24        TRAFFIC STOP      5T81
# 4                 4 2016-01-01 00:02:45       CHECK WELFARE      3X90
# ...             ...                 ...                 ...       ...
# 1267985     1616812 2023-12-31 22:44:38             DISPUTE      6E19
# 1267986     1616813 2023-12-31 22:44:38             DISPUTE      6E19
# 1267987     1616814 2023-12-31 22:44:38             DISPUTE      6E19
# 1267988     1616817 2023-12-31 22:56:40        TRAFFIC STOP      4F74
# 1267989     1616818 2023-12-31 22:56:40        TRAFFIC STOP      4F74
#
#         2 Call Sign                      Disposition
# 0              5E57                          ADVISED
# 1              4X40                          ADVISED
# 2              4E53                          ADVISED
# 3              5T81                          ADVISED
# 4              3F61                         ASSISTED
# ...             ...                              ...
# 1267985        4K97                     REPORT TAKEN
# 1267986        6E19                     REPORT TAKEN
# 1267987        5X51                     REPORT TAKEN
# 1267988        4F72  UNIFORM TRAFFIC CITATION ISSUED
# 1267989        4F74  UNIFORM TRAFFIC CITATION ISSUED
#
# [1267990 rows x 6 columns]

# %%
#Manually Finding the first occurrance of each call sign

target_call_signs = ["1J77", "3J78", "4J79"]

filtered_call_signs = clean_cad[clean_cad['Call Sign'].isin(target_call_signs)]

first_occurrence_call_sign = filtered_call_signs.groupby('Call Sign')['Call Time'].min()
first_1J77 = first_occurrence_call_sign['1J77']
first_3J78 = first_occurrence_call_sign['3J78']
first_4J79 = first_occurrence_call_sign['4J79']

last_occurrence = filtered_call_signs.groupby('Call Sign')['Call Time'].max()
last_1J77 = last_occurrence['1J77']
last_3J78 = last_occurrence['3J78']
last_4J79 = last_occurrence['4J79']


times_1J77 = {
    "First": first_1J77,
    "Last": last_1J77
}
times_3J78 = {
    "First": first_3J78,
    "Last": last_3J78
}
times_4J79 = {
    "First": first_4J79,
    "Last": last_4J79
}
call_sign_times = {
    "3J78": times_3J78,
    "1J77": times_1J77,
    "4J79": times_4J79
}
